# %% [markdown]
# # 01 - Data Prep
#
# This notebook loads the raw SugarWOD, leaderboard, and Open workout files and inspects their shape.

# %%
import pandas as pd
from pathlib import Path

root = Path('..')
training = pd.read_csv(root / 'data' / 'raw' / 'Daltonsworkouts.csv')
leaderboard = pd.read_csv(root / 'data' / 'raw' / 'crossfit_open_leaderboard.csv')
open_workouts = pd.read_csv(root / 'data' / 'raw' / 'crossfit_open_workouts.csv')

training.shape, leaderboard.shape, open_workouts.shape

# %%
training.head()

# %%
leaderboard.head()

# %%
open_workouts.head()

# %% [markdown]
# ## Notes
#
# - SugarWOD data is semi-structured and requires movement tagging.
# - Open leaderboard data provides yearly and event-level outcomes.
# - Open workout definitions provide the demand side of the analysis.
